# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
# !unzip -q PetImage.zip
# !ls
# Out:
# replace PetImage/Cat/cat.0.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: PetImage  PetImage.zip	sample_data

# %%
# !ls PetImage
# Out:
# Cat  Dog

# %%
import os

num_skipped = 0
for folder_name in ("Cat", "Dog"):
    folder_path = os.path.join("PetImage", folder_name)
    for fname in os.listdir(folder_path):
        fpath = os.path.join(folder_path, fname)
        try:
            fobj = open(fpath, "rb")
            is_jfif = tf.compat.as_bytes("JFIF") in fobj.peek(10)
        finally:
            fobj.close()

        if not is_jfif:
            num_skipped += 1
            # Delete corrupted image
            os.remove(fpath)

print("Deleted %d images" % num_skipped)
# Out:
# Deleted 0 images

# %%
image_size = (180, 180)
batch_size = 32

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "PetImage",
    validation_split=0.2,
    subset="training",
    seed=1337,
    image_size=image_size,
    batch_size=batch_size,
)
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "PetImage",
    validation_split=0.2,
    subset="validation",
    seed=1337,
    image_size=image_size,
    batch_size=batch_size,
)
# Out:
# Found 5413 files belonging to 2 classes.
# Using 4331 files for training.
# Found 5413 files belonging to 2 classes.
# Using 1082 files for validation.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(int(labels[i]))
        plt.axis("off")

# %%
data_augmentation = keras.Sequential(
    [
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.1),
    ]
)

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
    for i in range(9):
        augmented_images = data_augmentation(images)
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(augmented_images[0].numpy().astype("uint8"))
        plt.axis("off")

# %%
train_ds = train_ds.prefetch(buffer_size=32)
val_ds = val_ds.prefetch(buffer_size=32)

# %%
def make_model(input_shape, num_classes):
    inputs = keras.Input(shape=input_shape)
    # Image augmentation block
    x = data_augmentation(inputs)

    # Entry block
    x = layers.Rescaling(1.0 / 255)(x)
    x = layers.Conv2D(32, 3, strides=2, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    x = layers.Conv2D(64, 3, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    previous_block_activation = x  # Set aside residual

    for size in [128, 256, 512, 728]:
        x = layers.Activation("relu")(x)
        x = layers.SeparableConv2D(size, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.Activation("relu")(x)
        x = layers.SeparableConv2D(size, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.MaxPooling2D(3, strides=2, padding="same")(x)

        # Project residual
        residual = layers.Conv2D(size, 1, strides=2, padding="same")(
            previous_block_activation
        )
        x = layers.add([x, residual])  # Add back residual
        previous_block_activation = x  # Set aside next residual

    x = layers.SeparableConv2D(1024, 3, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    x = layers.GlobalAveragePooling2D()(x)
    if num_classes == 2:
        activation = "sigmoid"
        units = 1
    else:
        activation = "softmax"
        units = num_classes

    x = layers.Dropout(0.5)(x)
    outputs = layers.Dense(units, activation=activation)(x)
    return keras.Model(inputs, outputs)


model = make_model(input_shape=image_size + (3,), num_classes=2)
keras.utils.plot_model(model, show_shapes=True)

# %%
epochs = 50

callbacks = [
    keras.callbacks.ModelCheckpoint("save_at_{epoch}.h5"),
]
model.compile(
    optimizer=keras.optimizers.Adam(1e-3),
    loss="binary_crossentropy",
    metrics=["accuracy"],
)
model.fit(
    train_ds, epochs=epochs, callbacks=callbacks, validation_data=val_ds,
)
# Out:
# Epoch 1/50
# 136/136 [==============================] - 54s 272ms/step - loss: 0.6964 - accuracy: 0.6285 - val_loss: 0.6819 - val_accuracy: 0.6238
# Epoch 2/50
# 136/136 [==============================] - 36s 261ms/step - loss: 0.6262 - accuracy: 0.6802 - val_loss: 0.7372 - val_accuracy: 0.6238
# Epoch 3/50
# 136/136 [==============================] - 37s 268ms/step - loss: 0.5771 - accuracy: 0.7197 - val_loss: 0.9748 - val_accuracy: 0.6238
# Epoch 4/50
# 136/136 [==============================] - 36s 263ms/step - loss: 0.5259 - accuracy: 0.7483 - val_loss: 0.5912 - val_accuracy: 0.6839
# Epoch 5/50
# 136/136 [==============================] - 36s 265ms/step - loss: 0.4965 - accuracy: 0.7719 - val_loss: 0.6883 - val_accuracy: 0.6969
# Epoch 6/50
# 136/136 [==============================] - 36s 265ms/step - loss: 0.4722 - accuracy: 0.7827 - val_loss: 0.5668 - val_accuracy: 0.6969
# Epoch 7/50
# 136/136 [==============================] - 36s 265ms/step - loss: 0.4463 - accuracy: 0.7940 - val_loss: 0.4809 - val_accuracy: 0.7782
# Epoch 8/50
# 136/136 [==============================] - 36s 265ms/step - loss: 0.4183 - accuracy: 0.8109 - val_loss: 0.4280 - val_accuracy: 0.8105
# Epoch 9/50
# 136/136 [==============================] - 36s 265ms/step - loss: 0.3994 - accuracy: 0.8222 - val_loss: 0.7310 - val_accuracy: 0.7079
# Epoch 10/50
# 136/136 [==============================] - 36s 265ms/step - loss: 0.3757 - accuracy: 0.8342 - val_loss: 0.4435 - val_accuracy: 0.8013
# Epoch 11/50
# 136/136 [==============================] - 36s 266ms/step - loss: 0.3719 - accuracy: 0.8361 - val_loss: 0.4737 - val_accuracy: 0.8142
# Epoch 12/50
# 136/136 [==============================] - 36s 263ms/step - loss: 0.3499 - accuracy: 0.8481 - val_loss: 0.5157 - val_accuracy: 0.7819
# Epoch 13/50
# 136/136 [==============================] - 36s 266ms/step - loss: 0.3353 - accuracy: 0.8534 - val_loss: 0.7333 - val_accuracy: 0.7292
# Epoch 14/50
# 136/136 [==============================] - 37s 269ms/step - loss: 0.3275 - accuracy: 0.8596 - val_loss: 0.7024 - val_accuracy: 0.7431
# Epoch 15/50
# 136/136 [==============================] - 37s 268ms/step - loss: 0.2999 - accuracy: 0.8781 - val_loss: 0.3081 - val_accuracy: 0.8762
# Epoch 16/50
# 136/136 [==============================] - 37s 268ms/step - loss: 0.2945 - accuracy: 0.8788 - val_loss: 0.3936 - val_accuracy: 0.8327
# Epoch 17/50
# 136/136 [==============================] - 36s 265ms/step - loss: 0.2812 - accuracy: 0.8846 - val_loss: 0.7245 - val_accuracy: 0.7486
# Epoch 18/50
# 136/136 [==============================] - 36s 264ms/step - loss: 0.2668 - accuracy: 0.8899 - val_loss: 0.3493 - val_accuracy: 0.8762
# Epoch 19/50
# 136/136 [==============================] - 36s 264ms/step - loss: 0.2577 - accuracy: 0.8936 - val_loss: 0.2577 - val_accuracy: 0.8900
# Epoch 20/50
# 136/136 [==============================] - 36s 265ms/step - loss: 0.2514 - accuracy: 0.8963 - val_loss: 0.3372 - val_accuracy: 0.8669
# Epoch 21/50
# 136/136 [==============================] - 36s 265ms/step - loss: 0.2401 - accuracy: 0.9056 - val_loss: 0.2518 - val_accuracy: 0.8946
# Epoch 22/50
# 136/136 [==============================] - 36s 265ms/step - loss: 0.2412 - accuracy: 0.9026 - val_loss: 0.2551 - val_accuracy: 0.8891
# Epoch 23/50
# 136/136 [==============================] - 36s 264ms/step - loss: 0.2278 - accuracy: 0.9067 - val_loss: 0.3030 - val_accuracy: 0.8780
# Epoch 24/50
# 136/136 [==============================] - 36s 265ms/step - loss: 0.2174 - accuracy: 0.9116 - val_loss: 0.4147 - val_accuracy: 0.8420
# Epoch 25/50
# 136/136 [==============================] - 36s 266ms/step - loss: 0.1926 - accuracy: 0.9254 - val_loss: 0.2230 - val_accuracy: 0.9094
# Epoch 26/50
# 136/136 [==============================] - 36s 266ms/step - loss: 0.2286 - accuracy: 0.9097 - val_loss: 0.2296 - val_accuracy: 0.9039
# Epoch 27/50
# 136/136 [==============================] - 36s 265ms/step - loss: 0.1873 - accuracy: 0.9247 - val_loss: 0.3058 - val_accuracy: 0.8946
# Epoch 28/50
# 136/136 [==============================] - 36s 265ms/step - loss: 0.1723 - accuracy: 0.9293 - val_loss: 0.2347 - val_accuracy: 0.9076
# Epoch 29/50
# 136/136 [==============================] - 36s 263ms/step - loss: 0.1979 - accuracy: 0.9245 - val_loss: 0.2306 - val_accuracy: 0.9085
# Epoch 30/50
# 136/136 [==============================] - 36s 265ms/step - loss: 0.1787 - accuracy: 0.9284 - val_loss: 0.3095 - val_accuracy: 0.8826
# Epoch 31/50
# 136/136 [==============================] - 36s 263ms/step - loss: 0.1698 - accuracy: 0.9312 - val_loss: 0.2351 - val_accuracy: 0.9113
# Epoch 32/50
# 136/136 [==============================] - 36s 264ms/step - loss: 0.1817 - accuracy: 0.9270 - val_loss: 0.2558 - val_accuracy: 0.8900
# Epoch 33/50
# 136/136 [==============================] - 36s 263ms/step - loss: 0.1560 - accuracy: 0.9335 - val_loss: 0.2414 - val_accuracy: 0.9104
# Epoch 34/50
# 136/136 [==============================] - 36s 263ms/step - loss: 0.1466 - accuracy: 0.9425 - val_loss: 0.3725 - val_accuracy: 0.8752
# Epoch 35/50
# 136/136 [==============================] - 37s 267ms/step - loss: 0.1554 - accuracy: 0.9388 - val_loss: 0.3172 - val_accuracy: 0.8909
# Epoch 36/50
# 136/136 [==============================] - 36s 264ms/step - loss: 0.1385 - accuracy: 0.9444 - val_loss: 0.2293 - val_accuracy: 0.9104
# Epoch 37/50
# 136/136 [==============================] - 36s 265ms/step - loss: 0.1407 - accuracy: 0.9437 - val_loss: 0.2564 - val_accuracy: 0.9113
# Epoch 38/50
# 136/136 [==============================] - 36s 265ms/step - loss: 0.1307 - accuracy: 0.9483 - val_loss: 0.2534 - val_accuracy: 0.8946
# Epoch 39/50
# 136/136 [==============================] - 36s 264ms/step - loss: 0.1300 - accuracy: 0.9460 - val_loss: 0.2212 - val_accuracy: 0.9122
# Epoch 40/50
# 136/136 [==============================] - 37s 267ms/step - loss: 0.1385 - accuracy: 0.9450 - val_loss: 0.3252 - val_accuracy: 0.8734
# Epoch 41/50
# 136/136 [==============================] - 36s 266ms/step - loss: 0.1250 - accuracy: 0.9499 - val_loss: 0.1657 - val_accuracy: 0.9362
# Epoch 42/50
# 136/136 [==============================] - 37s 266ms/step - loss: 0.1198 - accuracy: 0.9508 - val_loss: 0.3087 - val_accuracy: 0.9002
# Epoch 43/50
# 136/136 [==============================] - 36s 265ms/step - loss: 0.1276 - accuracy: 0.9478 - val_loss: 0.5527 - val_accuracy: 0.8512
# Epoch 44/50
# 136/136 [==============================] - 37s 267ms/step - loss: 0.1157 - accuracy: 0.9534 - val_loss: 0.2462 - val_accuracy: 0.9113
# Epoch 45/50
# 136/136 [==============================] - 36s 265ms/step - loss: 0.1104 - accuracy: 0.9598 - val_loss: 0.3861 - val_accuracy: 0.8762
# Epoch 46/50
# 136/136 [==============================] - 37s 267ms/step - loss: 0.1145 - accuracy: 0.9561 - val_loss: 0.2623 - val_accuracy: 0.9140
# Epoch 47/50
# 136/136 [==============================] - 36s 264ms/step - loss: 0.1064 - accuracy: 0.9575 - val_loss: 0.2254 - val_accuracy: 0.9187
# Epoch 48/50
# 136/136 [==============================] - 36s 266ms/step - loss: 0.1051 - accuracy: 0.9601 - val_loss: 0.3596 - val_accuracy: 0.8872
# Epoch 49/50
# 136/136 [==============================] - 36s 263ms/step - loss: 0.0987 - accuracy: 0.9601 - val_loss: 0.2464 - val_accuracy: 0.9113
# Epoch 50/50
# 136/136 [==============================] - 36s 263ms/step - loss: 0.1024 - accuracy: 0.9598 - val_loss: 0.1837 - val_accuracy: 0.9335

# %%
img = keras.preprocessing.image.load_img(
    "18.jpg", target_size=image_size
)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)  # Create batch axis

predictions = model.predict(img_array)
score = predictions[0]
print(
    "This image is %.2f percent cat and %.2f percent dog."
    % (100 * (1 - score), 100 * score)
)
# Out:
# This image is 0.00 percent cat and 100.00 percent dog.
